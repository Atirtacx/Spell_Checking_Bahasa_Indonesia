# %%
import re
from collections import Counter
from time import perf_counter

def words(text): return re.findall(r'\w+', text.lower())

path_corpus = "D:\Dokumen\SKRIPSI\Language Model\DATASET\wortschatz.leipzig.txt"

WORDS = Counter(words(open(path_corpus, encoding="utf8").read()))

def P(word, N=sum(WORDS.values())): 
    return WORDS[word] / N

def correction(word): 
    return max(candidates(word), key=P)

def candidates(word): 
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    return set(w for w in words if w in WORDS)

def edits1(word):
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
text = "Ini adalah contoh kalimat yang akan di-tokenize."
tokens = words(text)

# Cetak hasil tokenizing
print(tokens)
# Out:
# ['ini', 'adalah', 'contoh', 'kalimat', 'yang', 'akan', 'di', 'tokenize']

# %%
correction('mengujar')
# Out:
# 'mengajar'

# %%
def edits1(word):
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

# %%
len(edits1('mengujar'))
# Out:
# 442

# %%
def known(words): return set(w for w in words if w in WORDS)
known(edits1('mengujar'))
# Out:
# {'mengajar', 'mengejar'}

# %%
def edits2(word): return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
len(set(edits2('mengejar')))
# Out:
# 90901

# %%
known(edits2('mengejar'))
# Out:
# {'mengajak',
#  'mengajar',
#  'mengajari',
#  'mengakar',
#  'mengecam',
#  'mengecat',
#  'mengeja',
#  'mengejar',
#  'mengejek',
#  'mengena',
#  'mengenai',
#  'mengenal',
#  'mengeras',
#  'menggelar',
#  'menyebar',
#  'pengajar'}

# %%
known(edits2('mngejar'))
# Out:
# {'mengajar', 'mengeja', 'mengejar'}

# %%
def words(text): return re.findall(r'\w+', text.lower())
WORDS = Counter(words(open('D:\Dokumen\SKRIPSI\Language Model\DATASET\wortschatz.leipzig.txt', encoding="utf8").read()))
def P(word, N=sum(WORDS.values())): return WORDS[word] / N

# %%
len(WORDS)
# Out:
# 34805

# %%
sum(WORDS.values())
# Out:
# 171674

# %%
WORDS.most_common(10)
# Out:
# [('dan', 4644),
#  ('yang', 4520),
#  ('di', 3056),
#  ('pada', 2277),
#  ('dengan', 2012),
#  ('dari', 1986),
#  ('ini', 1835),
#  ('untuk', 1739),
#  ('dalam', 1417),
#  ('tahun', 1162)]

# %%
max(WORDS, key=P)
# Out:
# 'dan'

# %%
P('kucing')
# Out:
# 0.00011649987767512844

# %%
P('dan')
# Out:
# 0.027051271596164824

# %%
P('kalkulatif')
# Out:
# 0.0

# %%
def correction(word): return max(candidates(word), key=P)

def candidates(word): 
    return known([word]) or known(edits1(word)) or known(edits2(word)) or [word]

# %%
def unit_tests():
    assert correction('panh') == 'panah'              # insert
    assert correction('przjuryt') == 'prajurit'           # replace 2
    assert correction('minjadi') == 'menjadi'               # replace
    assert correction('merupan') == 'merupakan'       # insert 2
    assert correction('teersebut') == 'tersebut'            # delete
    assert correction('naivgasi') =='navigasi'                  # transpose
    assert correction('naivgasii') =='navigasi'                 # transpose + delete
    assert correction('memang') == 'memang'                     # known
    assert correction('kalkulatif') == 'kalkulatif' # unknown
    assert words('This is a TEST.') == ['this', 'is', 'a', 'test']
    assert Counter(words('This is a test. 123; A TEST this is.')) == (
           Counter({'123': 1, 'a': 2, 'is': 2, 'test': 2, 'this': 2}))
    assert len(WORDS) == 34805
    assert sum(WORDS.values()) == 171674
    assert WORDS.most_common(10) == [('dan', 4644),
            ('yang', 4520),
            ('di', 3056),
            ('pada', 2277),
            ('dengan', 2012),
            ('dari', 1986),
            ('ini', 1835),
            ('untuk', 1739),
            ('dalam', 1417),
            ('tahun', 1162)]
    assert WORDS['dan'] == 4644
    assert P('kalkulatif') == 0
    assert 0.01 < P('dan') < 0.04
    return 'unit_tests pass'

def spelltest(tests, verbose=False):
    import time
    start = time.perf_counter()
    good, unknown = 0, 0
    n = len(tests)
    for right, wrong in tests:
        w = correction(wrong)
        good += (w == right)
        if w != right:
            unknown += (right not in WORDS)
            if verbose:
                print('correction({}) => {} ({}); expected {} ({})'
                      .format(wrong, w, WORDS[w], right, WORDS[right]))
    dt = time.perf_counter() - start
    print('{:.0%} of {} correct ({:.0%} unknown) at {:.0f} words per second '
          .format(good / n, n, unknown / n, n / dt))

def Testset(lines):
    return [(right, wrong)
            for (right, wrongs) in (line.split(':') for line in lines)
            for wrong in wrongs.split()]

print(unit_tests())
spelltest(Testset(open('norvig_insertion.txt')), True)
# Out:
# unit_tests pass
# correction(sekkoolahh) => sekkoolahh (0); expected sekolah (126)
# correction(sekolahan) => sekolahan (1); expected sekolah (126)
# correction(bukuuuu) => bukuuuu (0); expected buku (78)
# correction(tman) => taman (37); expected teman (32)
# correction(makanan) => makanan (28); expected makan (28)
# correction(buung) => burung (37); expected bunga (36)
# correction(jalanan) => jalanan (11); expected jalan (109)
# correction(lapot) => dapat (442); expected laptop (1)
# correction(laptopan) => laporan (25); expected laptop (1)
# correction(matari) => materi (12); expected matahari (33)
# correction(lautann) => lautan (4); expected laut (86)
# correction(kucingan) => kuningan (2); expected kucing (20)
# correction(pelajarn) => pelajar (19); expected pelajaran (15)
# correction(putrii) => putri (40); expected puteri (8)
# correction(pisangan) => pasangan (43); expected pisang (3)
# correction(pisangan) => pasangan (43); expected pisang (3)
# correction(bauu) => baru (251); expected baju (7)
# correction(bajuan) => batuan (4); expected baju (7)
# correction(tass) => bass (4); expected tas (1)
# correction(taas) => atas (210); expected tas (1)
# correction(taas) => atas (210); expected tas (1)
# correction(tasss) => kasus (46); expected tas (1)
# correction(jamann) => jaman (1); expected jam (51)
# correction(mawaran) => kawasan (46); expected mawar (2)
# correction(lantaian) => lantaran (7); expected lantai (28)
# correction(kamaraan) => samaran (2); expected kamar (9)
# correction(matan) => matan (3); expected mata (64)
# correction(kkaaii) => kkaaii (0); expected kaki (41)
# correction(kai) => kai (1); expected kaki (41)
# correction(tanggan) => tanggal (195); expected tangan (35)
# correction(tanggan) => tanggal (195); expected tangan (35)
# correction(tanggaan) => tanggapan (7); expected tangan (35)
# correction(buahan) => buahan (5); expected buah (46)
# correction(meejaa) => menjaga (19); expected meja (8)
# correction(mejaan) => ejaan (2); expected meja (8)
# correction(pensilan) => pensiun (11); expected pensil (1)
# correction(kertasan) => bertahan (40); expected kertas (12)
# correction(topii) => topik (9); expected topi (7)
# correction(topii) => topik (9); expected topi (7)
# correction(topii) => topik (9); expected topi (7)
# correction(topian) => topan (1); expected topi (7)
# correction(roottii) => roottii (0); expected roti (7)
# correction(sapu) => sapu (1); expected sapi (6)
# correction(anjigaan) => anjigaan (0); expected anjing (11)
# correction(sepatuan) => selatan (97); expected sepatu (6)
# correction(bukitan) => bukan (45); expected bukit (17)
# correction(teluuran) => keluaran (3); expected telur (23)
# correction(bintangan) => rintangan (3); expected bintang (45)
# correction(cokolatt) => cokelat (7); expected coklat (4)
# correction(benderaan) => kendaraan (31); expected bendera (16)
# correction(bantall) => bantalan (7); expected bantal (0)
# correction(bantal) => bantul (1); expected bantal (0)
# correction(bantall) => bantalan (7); expected bantal (0)
# correction(bantall) => bantalan (7); expected bantal (0)
# correction(bantal) => bantul (1); expected bantal (0)
# correction(perahuan) => peraturan (23); expected perahu (9)
# correction(gunungan) => gubungan (1); expected gunung (49)
# correction(seranggaan) => serangan (53); expected serangga (8)
# correction(kumbangg) => kembang (5); expected kumbang (0)
# correction(kumbang) => kembang (5); expected kumbang (0)
# correction(kumbanng) => kembang (5); expected kumbang (0)
# correction(kumbang) => kembang (5); expected kumbang (0)
# correction(kumbangan) => sumbangan (4); expected kumbang (0)
# correction(sapuan) => satuan (7); expected sapu (1)
# correction(telppon) => telepon (7); expected telpon (0)
# correction(telpon) => telepon (7); expected telpon (0)
# correction(telpon) => telepon (7); expected telpon (0)
# correction(telppon) => telepon (7); expected telpon (0)
# correction(teleponan) => telepon (7); expected telpon (0)
# correction(jamu) => jamu (2); expected jambu (0)
# correction(jambu) => bambu (8); expected jambu (0)
# correction(jambbu) => bambu (8); expected jambu (0)
# correction(jambu) => bambu (8); expected jambu (0)
# correction(jambuan) => jamuan (1); expected jambu (0)
# correction(cerminan) => permainan (42); expected cermin (2)
# correction(burungan) => kurungan (2); expected burung (37)
# correction(televisian) => television (2); expected televisi (35)
# correction(rook) => rock (12); expected rok (1)
# correction(rook) => rock (12); expected rok (1)
# correction(rookk) => rokok (3); expected rok (1)
# correction(bulanan) => bulanan (2); expected bulan (197)
# correction(keretaan) => kerelaan (1); expected kereta (58)
# correction(pensilan) => pensiun (11); expected pensil (1)
# correction(koperan) => peran (39); expected koper (2)
# correction(taas) => atas (210); expected tas (1)
# correction(taas) => atas (210); expected tas (1)
# correction(tass) => bass (4); expected tas (1)
# correction(tass) => bass (4); expected tas (1)
# correction(mejaan) => ejaan (2); expected meja (8)
# correction(pensilan) => pensiun (11); expected pensil (1)
# correction(kertasan) => bertahan (40); expected kertas (12)
# correction(topii) => topik (9); expected topi (7)
# correction(toppii) => topik (9); expected topi (7)
# correction(topian) => topan (1); expected topi (7)
# correction(roottii) => roottii (0); expected roti (7)
# correction(sapu) => sapu (1); expected sapi (6)
# correction(anjigaan) => anjigaan (0); expected anjing (11)
# correction(kacan) => kanan (30); expected kaca (17)
# correction(pirangan) => piringan (1); expected piring (2)
# correction(lasi) => lagi (133); expected laci (1)
# correction(lasi) => lagi (133); expected laci (1)
# correction(lasi) => lagi (133); expected laci (1)
# correction(lasian) => losian (1); expected laci (1)
# correction(guunting) => genting (3); expected gunting (0)
# correction(gunting) => genting (3); expected gunting (0)
# correction(gunting) => genting (3); expected gunting (0)
# correction(guunting) => genting (3); expected gunting (0)
# correction(guntingan) => suntingan (1); expected gunting (0)
# correction(sepatuan) => selatan (97); expected sepatu (6)
# correction(lampuan) => lampuan (1); expected lampu (7)
# correction(lilinan) => pilihan (20); expected lilin (2)
# correction(tanggan) => tanggal (195); expected tangan (35)
# correction(tanggann) => tanggal (195); expected tangan (35)
# correction(tanggaan) => tanggapan (7); expected tangan (35)
# correction(kucingan) => kuningan (2); expected kucing (20)
# correction(jalanan) => jalanan (11); expected jalan (109)
# correction(jamann) => jaman (1); expected jam (51)
# correction(matan) => matan (3); expected mata (64)
# correction(buung) => burung (37); expected bunga (36)
# correction(mkaan) => makan (28); expected makanan (28)
# correction(mkanan) => kanan (30); expected makanan (28)
# correction(kuci) => suci (21); expected kucing (20)
# correction(koompooter) => koompooter (0); expected komputer (43)
# correction(kamraa) => karya (73); expected kamera (20)
# correction(senndal) => sentral (9); expected sendal (0)
# correction(sendaal) => sentral (9); expected sendal (0)
# correction(senddall) => kendall (1); expected sendal (0)
# correction(seendal) => kendal (4); expected sendal (0)
# correction(ssendal) => kendal (4); expected sendal (0)
# correction(senndal) => sentral (9); expected sendal (0)
# correction(sendaal) => sentral (9); expected sendal (0)
# correction(senddall) => kendall (1); expected sendal (0)
# correction(seendal) => kendal (4); expected sendal (0)
# correction(ssendal) => kendal (4); expected sendal (0)
# correction(gallasxi) => gallasxi (0); expected galaksi (7)
# correction(konpsirasi) => konpsirasi (0); expected konspirasi (0)
# correction(konspiirasi) => konspiirasi (0); expected konspirasi (0)
# correction(konspirasii) => konspirasii (0); expected konspirasi (0)
# correction(konspiras) => konspiras (0); expected konspirasi (0)
# correction(konspiraasi) => konspiraasi (0); expected konspirasi (0)
# correction(jenglott) => jenglott (0); expected jenglot (0)
# correction(jennglot) => jennglot (0); expected jenglot (0)
# correction(jenlot) => bendot (1); expected jenglot (0)
# correction(sinematografii) => sinematografii (0); expected sinematografi (0)
# correction(sinematograffi) => sinematograffi (0); expected sinematografi (0)
# correction(sinmatografi) => sinmatografi (0); expected sinematografi (0)
# correction(quassar) => quassar (0); expected quasar (0)
# correction(quasarr) => quasarr (0); expected quasar (0)
# correction(quasar) => dasar (61); expected quasar (0)
# correction(quassarr) => quassarr (0); expected quasar (0)
# correction(quasarr) => quasarr (0); expected quasar (0)
# correction(intuiti) => intuitif (2); expected intuisi (1)
# correction(inuitisi) => inkuisisi (4); expected intuisi (1)
# correction(kaleidoskopp) => kaleidoskopp (0); expected kaleidoskop (0)
# correction(kaleidoskoo) => kaleidoskoo (0); expected kaleidoskop (0)
# correction(kaleidoskoop) => kaleidoskoop (0); expected kaleidoskop (0)
# correction(kalaidoskop) => kalaidoskop (0); expected kaleidoskop (0)
# correction(klarifikasii) => klasifikasi (5); expected klarifikasi (0)
# correction(klarifikassii) => klarifikassii (0); expected klarifikasi (0)
# correction(klarrifikasi) => klasifikasi (5); expected klarifikasi (0)
# correction(klarifikassii) => klarifikassii (0); expected klarifikasi (0)
# correction(klaryfikasi) => klasifikasi (5); expected klarifikasi (0)
# correction(enntropi) => sintropi (1); expected entropi (0)
# correction(enttropii) => enttropii (0); expected entropi (0)
# correction(entropii) => entropii (0); expected entropi (0)
# correction(enntropi) => sintropi (1); expected entropi (0)
# correction(enttroppi) => enttroppi (0); expected entropi (0)
# correction(akupukntur) => akupukntur (0); expected akupunktur (0)
# correction(akupuktur) => akupuktur (0); expected akupunktur (0)
# correction(akupunktuur) => akupunktuur (0); expected akupunktur (0)
# correction(akupuntuur) => akupuntuur (0); expected akupunktur (0)
# correction(akupnuktur) => akupnuktur (0); expected akupunktur (0)
# correction(ekoosytem) => ekoosytem (0); expected ekosistem (2)
# correction(monollog) => monollog (0); expected monolog (0)
# correction(monolog) => menolong (9); expected monolog (0)
# correction(monologg) => menolong (9); expected monolog (0)
# correction(monloog) => moncong (1); expected monolog (0)
# correction(monolog) => menolong (9); expected monolog (0)
# correction(prestidigatasi) => prestidigatasi (0); expected prestidigitasi (0)
# correction(prestidigiatsi) => prestidigiatsi (0); expected prestidigitasi (0)
# correction(prestidigitassi) => prestidigitassi (0); expected prestidigitasi (0)
# correction(prestidigitasii) => prestidigitasii (0); expected prestidigitasi (0)
# correction(prestidigiatsii) => prestidigiatsii (0); expected prestidigitasi (0)
# correction(simbioosis) => simbioosis (0); expected simbiosis (0)
# correction(simbiosiss) => simbiosiss (0); expected simbiosis (0)
# correction(simbiosiis) => simbiosiis (0); expected simbiosis (0)
# correction(simbioosis) => simbioosis (0); expected simbiosis (0)
# correction(simbioosiis) => simbioosiis (0); expected simbiosis (0)
# correction(konglometrat) => konglometrat (0); expected konglomerat (0)
# correction(konglomeraat) => konglomeraat (0); expected konglomerat (0)
# correction(konglomeratt) => konglomeratt (0); expected konglomerat (0)
# correction(konnglomerat) => konnglomerat (0); expected konglomerat (0)
# correction(konglomarat) => konglomarat (0); expected konglomerat (0)
# correction(proporssii) => proposisi (6); expected proporsi (4)
# correction(propositi) => proposisi (6); expected proporsi (4)
# correction(eksplotasi) => eksplorasi (1); expected eksploitasi (1)
# correction(eksplorasi) => eksplorasi (1); expected eksploitasi (1)
# correction(kongragasi) => kongragasi (0); expected kongregasi (0)
# correction(konngregasi) => konngregasi (0); expected kongregasi (0)
# correction(kongregasii) => kongregasii (0); expected kongregasi (0)
# correction(konggrogasi) => konggrogasi (0); expected kongregasi (0)
# correction(melankollis) => melankollis (0); expected melankolis (0)
# correction(melankoliss) => melankoliss (0); expected melankolis (0)
# correction(melankoliss) => melankoliss (0); expected melankolis (0)
# correction(ojjek) => objek (22); expected ojek (1)
# correction(quottient) => quottient (0); expected quotient (0)
# correction(quottient) => quottient (0); expected quotient (0)
# correction(quottient) => quottient (0); expected quotient (0)
# correction(subverssif) => subverssif (0); expected subversif (0)
# correction(subversiif) => subversiif (0); expected subversif (0)
# correction(subverssif) => subverssif (0); expected subversif (0)
# correction(subverrsif) => subverrsif (0); expected subversif (0)
# correction(terass) => terasa (7); expected teras (3)
# correction(terass) => terasa (7); expected teras (3)
# correction(terass) => terasa (7); expected teras (3)
# correction(urgenssi) => urgenssi (0); expected urgensi (0)
# correction(urgensi) => agensi (6); expected urgensi (0)
# correction(urgenssi) => urgenssi (0); expected urgensi (0)
# correction(urgensii) => urgensii (0); expected urgensi (0)
# correction(urgensi) => agensi (6); expected urgensi (0)
# correction(vesspa) => hessa (1); expected vespa (0)
# correction(vesspaa) => vesspaa (0); expected vespa (0)
# correction(vessspa) => vessspa (0); expected vespa (0)
# correction(vessspa) => vessspa (0); expected vespa (0)
# correction(vessspaa) => vessspaa (0); expected vespa (0)
# correction(wahu) => tahu (28); expected wahyu (4)
# correction(xenofobii) => xenofobii (0); expected xenofobi (0)
# correction(xenofobii) => xenofobii (0); expected xenofobi (0)
# correction(biisu) => biksu (5); expected bisu (3)
# correction(bissu) => biksu (5); expected bisu (3)
# correction(dasterr) => master (4); expected daster (0)
# correction(dasterr) => master (4); expected daster (0)
# correction(dasterr) => master (4); expected daster (0)
# correction(dastter) => master (4); expected daster (0)
# correction(dasterr) => master (4); expected daster (0)
# correction(eekor) => seekor (16); expected ekor (13)
# correction(eekorr) => seekor (16); expected ekor (13)
# correction(faja) => raja (111); expected fajar (4)
# correction(gulaii) => mulai (155); expected gulai (0)
# correction(gulaai) => mulai (155); expected gulai (0)
# correction(gulai) => mulai (155); expected gulai (0)
# correction(guulai) => mulai (155); expected gulai (0)
# correction(jutan) => juta (80); expected jutaan (1)
# correction(nungu) => ungu (3); expected nunggu (1)
# correction(otto) => otto (3); expected otot (10)
# correction(quaret) => maret (59); expected quartet (0)
# correction(quarttet) => quarttet (0); expected quartet (0)
# correction(quaret) => maret (59); expected quartet (0)
# correction(quarttett) => quarttett (0); expected quartet (0)
# correction(gembiraa) => gembiraa (0); expected gembira (0)
# correction(gembirah) => gembirah (0); expected gembira (0)
# correction(gemira) => gempa (10); expected gembira (0)
# correction(gembiraa) => gembiraa (0); expected gembira (0)
# correction(gembirah) => gembirah (0); expected gembira (0)
# correction(jangkik) => jangka (15); expected jangkrik (0)
# correction(janggkrik) => janggkrik (0); expected jangkrik (0)
# correction(janggkrik) => janggkrik (0); expected jangkrik (0)
# correction(optiimis) => optimus (2); expected optimis (0)
# correction(optiimis) => optimus (2); expected optimis (0)
# correction(optimiss) => optimus (2); expected optimis (0)
# correction(optimiss) => optimus (2); expected optimis (0)
# 73% of 958 correct (15% unknown) at 29 words per second

# %%
print(unit_tests())
spelltest(Testset(open('norvig_deletion.txt')), True)
# Out:
# unit_tests pass
# correction(mkanan) => kanan (30); expected makanan (28)
# correction(maaan) => makan (28); expected makanan (28)
# correction(tepon) => temon (1); expected telepon (7)
# correction(melis) => medis (12); expected menulis (50)
# correction(pitu) => itu (770); expected pintu (31)
# correction(pelis) => pelvis (1); expected penulis (32)
# correction(seolah) => seolah (3); expected sekolah (126)
# correction(solah) => salah (176); expected sekolah (126)
# correction(kaar) => kabar (18); expected kamar (9)
# correction(baa) => baja (13); expected bahasa (203)
# correction(jan) => jan (3); expected jalan (109)
# correction(sdiri) => diri (128); expected sendiri (152)
# correction(seri) => seri (39); expected sendiri (152)
# correction(temperat) => tempat (179); expected temperatur (6)
# correction(dua) => dua (252); expected dunia (170)
# correction(akir) => air (158); expected akhir (97)
# correction(aki) => aki (1); expected akhir (97)
# correction(jenda) => benda (36); expected jendela (6)
# correction(kuci) => suci (21); expected kucing (20)
# correction(gu) => g (17); expected guru (51)
# correction(gbar) => gear (4); expected gambar (43)
# correction(tagan) => taman (37); expected tangan (35)
# correction(wara) => para (279); expected warna (63)
# correction(bemain) => pemain (57); expected bermain (49)
# correction(seang) => sedang (87); expected senang (16)
# correction(seang) => sedang (87); expected senang (16)
# correction(kmarin) => marin (1); expected kemarin (1)
# correction(pemelajaran) => pemelajaran (1); expected pembelajaran (13)
# correction(komunikas) => komunitas (25); expected komunikasi (24)
# correction(pembangun) => pembangun (1); expected pembangunan (53)
# correction(lingkug) => linglung (1); expected lingkungan (37)
# correction(kebikan) => kebaikan (3); expected kebijakan (34)
# correction(abtrk) => batak (5); expected abstrak (1)
# correction(idosinkrasi) => idosinkrasi (0); expected idiosinkrasi (0)
# correction(idiosinrasi) => idiosinrasi (0); expected idiosinkrasi (0)
# correction(idiosinkasi) => idiosinkasi (0); expected idiosinkrasi (0)
# correction(inefisen) => inefisen (0); expected inefisien (0)
# correction(inefisien) => efisien (9); expected inefisien (0)
# correction(infisien) => efisien (9); expected inefisien (0)
# correction(abtrusitas) => abtrusitas (0); expected abstrusitas (0)
# correction(abtsitas) => abtsitas (0); expected abstrusitas (0)
# correction(abrusitas) => abrusitas (0); expected abstrusitas (0)
# correction(perkas) => berkas (17); expected perkakas (5)
# correction(perkak) => perak (14); expected perkakas (5)
# correction(melnkolis) => melnkolis (0); expected melankolis (0)
# correction(melnkolis) => melnkolis (0); expected melankolis (0)
# correction(melakolis) => melakolis (0); expected melankolis (0)
# correction(ektik) => etik (2); expected eklektik (0)
# correction(eklktik) => klitik (2); expected eklektik (0)
# correction(eklitik) => klitik (2); expected eklektik (0)
# correction(efemisme) => efemisme (0); expected eufemisme (0)
# correction(eufemise) => eufemise (0); expected eufemisme (0)
# correction(eufimisme) => eufimisme (0); expected eufemisme (0)
# correction(perspi) => versi (54); expected persepsi (1)
# correction(perspei) => persegi (16); expected persepsi (1)
# correction(persei) => persegi (16); expected persepsi (1)
# correction(kisan) => kisah (22); expected kiasan (3)
# correction(monon) => konon (9); expected monoton (1)
# correction(resilin) => resimen (7); expected resilien (0)
# correction(reslien) => resimen (7); expected resilien (0)
# correction(resili) => risili (1); expected resilien (0)
# correction(kredibl) => kredit (4); expected kredibel (0)
# correction(kedibel) => kedubes (1); expected kredibel (0)
# correction(kredebil) => kredebil (0); expected kredibel (0)
# correction(intelk) => intens (1); expected intelek (0)
# correction(intlek) => intake (2); expected intelek (0)
# correction(inteleg) => inteleg (0); expected intelek (0)
# correction(kolabratif) => kolabratif (0); expected kolaboratif (0)
# correction(klabratif) => klabratif (0); expected kolaboratif (0)
# correction(kolaratif) => komparatif (1); expected kolaboratif (0)
# correction(apresi) => agresi (2); expected apresiasi (2)
# correction(kolosal) => kolonial (10); expected kolosal (0)
# correction(kosolal) => kosolal (0); expected kolosal (0)
# correction(kolsal) => kolam (15); expected kolosal (0)
# correction(persii) => persia (10); expected presisi (3)
# correction(elaborasi) => kolaborasi (4); expected elaborasi (0)
# correction(elaborai) => elaborai (0); expected elaborasi (0)
# correction(elaborsi) => aborsi (3); expected elaborasi (0)
# correction(fantastis) => fantastic (1); expected fantastis (0)
# correction(fantstis) => fantastic (1); expected fantastis (0)
# correction(fantatis) => fantasi (4); expected fantastis (0)
# correction(objekif) => objek (22); expected objektif (0)
# correction(objetif) => objetif (0); expected objektif (0)
# correction(sensif) => seni (45); expected sensitif (1)
# correction(dilem) => dalem (5); expected dilema (1)
# correction(konseptul) => konseptor (1); expected konseptual (0)
# correction(konseptal) => konseptor (1); expected konseptual (0)
# correction(teknikal) => teknik (30); expected teknikal (0)
# correction(teknikl) => teknik (30); expected teknikal (0)
# correction(teknial) => teknik (30); expected teknikal (0)
# correction(aktal) => akal (6); expected aktual (2)
# correction(sarjna) => sarana (20); expected sarjana (11)
# correction(sajana) => sarana (20); expected sarjana (11)
# correction(monter) => monster (5); expected moneter (2)
# correction(pragmatis) => dramatis (2); expected pragmatis (0)
# correction(pragmats) => pragmats (0); expected pragmatis (0)
# correction(pragmtis) => praktis (5); expected pragmatis (0)
# correction(kolarasi) => koperasi (5); expected kolaborasi (4)
# correction(konstusi) => konstruksi (13); expected konstitusi (8)
# correction(integras) => integral (3); expected integritas (2)
# correction(otentik) => identik (4); expected otentik (0)
# correction(oentik) => bentuk (100); expected otentik (0)
# correction(otntik) => titik (39); expected otentik (0)
# correction(teorts) => terus (56); expected teoritis (2)
# correction(kualitaf) => kualitas (21); expected kualitatif (2)
# correction(rekasi) => reaksi (18); expected rekreasi (5)
# correction(senralisasi) => serialisasi (1); expected sentralisasi (0)
# correction(senraliasi) => senraliasi (0); expected sentralisasi (0)
# correction(konsistensi) => konsisten (5); expected konsistensi (0)
# correction(konsitensi) => konstituensi (1); expected konsistensi (0)
# correction(konsisteni) => konsisten (5); expected konsistensi (0)
# correction(akrt) => art (3); expected akurat (4)
# correction(kreaf) => korea (38); expected kreatif (4)
# correction(kabilitas) => fasilitas (31); expected kapabilitas (1)
# correction(fenomenal) => fenomena (9); expected fenomenal (0)
# correction(fenomenall) => fenomena (9); expected fenomenal (0)
# correction(fenomal) => feodal (1); expected fenomenal (0)
# correction(kolosal) => kolonial (10); expected kolosal (0)
# correction(kolsal) => kolam (15); expected kolosal (0)
# correction(kosolal) => kosolal (0); expected kolosal (0)
# correction(dimei) => dimer (1); expected dimensi (8)
# correction(faktual) => aktual (2); expected faktual (0)
# correction(fakttual) => aktual (2); expected faktual (0)
# correction(faktul) => waktu (158); expected faktual (0)
# correction(pemberuan) => pemberian (6); expected pembaruan (5)
# correction(pemberun) => pemeran (18); expected pembaruan (5)
# correction(ekslusivitas) => ekslusivitas (0); expected eksklusivitas (0)
# correction(desentralisai) => desentralisai (0); expected desentralisasi (0)
# correction(desentralisi) => desentralisi (0); expected desentralisasi (0)
# correction(desntralisasi) => desntralisasi (0); expected desentralisasi (0)
# correction(destrutif) => destrutif (0); expected destruktif (0)
# correction(desruktif) => desruktif (0); expected destruktif (0)
# correction(kemapanan) => keamanan (27); expected kemapanan (0)
# correction(kemapnan) => kemanan (1); expected kemapanan (0)
# correction(kemanpanan) => ketampanan (1); expected kemapanan (0)
# correction(pluralsitas) => pluralsitas (0); expected pluralitas (0)
# correction(pluralits) => plurals (1); expected pluralitas (0)
# correction(orgaisi) => organis (1); expected organisasi (44)
# correction(transpransi) => transpransi (0); expected transparansi (0)
# correction(transparnsi) => transparnsi (0); expected transparansi (0)
# correction(imajinatif) => imajinasi (2); expected imajinatif (0)
# correction(imajntif) => imajntif (0); expected imajinatif (0)
# correction(imajinatf) => imajinasi (2); expected imajinatif (0)
# correction(kapats) => kapas (2); expected kapasitas (12)
# correction(korup) => korut (1); expected korupsi (3)
# correction(korpsi) => korps (9); expected korupsi (3)
# correction(hiberni) => diberi (41); expected hibernasi (0)
# correction(hibersi) => diberi (41); expected hibernasi (0)
# correction(prospektif) => perspektif (2); expected prospektif (0)
# correction(propektif) => properti (14); expected prospektif (0)
# correction(prspektif) => perspektif (2); expected prospektif (0)
# correction(retrospekti) => retrospekti (0); expected retrospektif (0)
# correction(retrospeftif) => retrospeftif (0); expected retrospektif (0)
# correction(konsolisasi) => konsolisasi (0); expected konsolidasi (0)
# correction(konsolidsi) => konsolidsi (0); expected konsolidasi (0)
# correction(kolabratif) => kolabratif (0); expected kolaboratif (0)
# correction(klabratif) => klabratif (0); expected kolaboratif (0)
# correction(kolaratif) => komparatif (1); expected kolaboratif (0)
# correction(evalusi) => evolusi (6); expected evaluasi (3)
# correction(movasi) => lokasi (36); expected motivasi (1)
# correction(kompatibilitass) => kompatibilitass (0); expected kompatibilitas (0)
# correction(kompatibilits) => kompatibilits (0); expected kompatibilitas (0)
# correction(organisatri) => organisasi (44); expected organisatoris (1)
# correction(korelsi) => koreksi (1); expected korelasi (1)
# correction(kolabratif) => kolabratif (0); expected kolaborasi (4)
# correction(klabratif) => klabratif (0); expected kolaborasi (4)
# correction(kolaratif) => komparatif (1); expected kolaborasi (4)
# correction(ekspresif) => ekspresi (7); expected ekspresif (0)
# correction(eksprssif) => ekspresi (7); expected ekspresif (0)
# correction(eksresif) => ekspresi (7); expected ekspresif (0)
# correction(konseptul) => konseptor (1); expected konseptual (0)
# correction(konseptal) => konseptor (1); expected konseptual (0)
# correction(kolabrat) => labrat (1); expected kolaborasi (4)
# correction(klabrat) => labrat (1); expected kolaborasi (4)
# correction(kolarati) => kolarati (0); expected kolaborasi (4)
# correction(transpransi) => transpransi (0); expected transparansi (0)
# correction(transparnsi) => transparnsi (0); expected transparansi (0)
# correction(korelsi) => koreksi (1); expected korelasi (1)
# correction(kolabratif) => kolabratif (0); expected kolaborasi (4)
# correction(klabratif) => klabratif (0); expected kolaborasi (4)
# correction(kolaratif) => komparatif (1); expected kolaborasi (4)
# 67% of 550 correct (19% unknown) at 30 words per second

# %%
print(unit_tests())
spelltest(Testset(open('norvig_substitution.txt')), True)
# Out:
# unit_tests pass
# correction(txman) => taman (37); expected teman (32)
# correction(sekula) => semula (7); expected sekolah (126)
# correction(sekoa) => serta (150); expected sekolah (126)
# correction(sekalh) => sekali (46); expected sekolah (126)
# correction(mkan) => akan (448); expected makan (28)
# correction(mkann) => akan (448); expected makan (28)
# correction(makn) => maka (80); expected makan (28)
# correction(putri) => putri (40); expected puteri (8)
# correction(putry) => putra (54); expected puteri (8)
# correction(putrei) => putri (40); expected puteri (8)
# correction(bermyn) => berwyn (1); expected bermain (49)
# correction(putre) => putra (54); expected puteri (8)
# correction(mgambar) => gambar (43); expected menggambar (5)
# correction(mngambar) => gambar (43); expected menggambar (5)
# correction(kuching) => kuching (1); expected kucing (20)
# correction(loptap) => lontar (2); expected laptop (1)
# correction(kls) => kls (1); expected kelas (61)
# correction(kella) => kalla (4); expected kelas (61)
# correction(kpe) => ke (842); expected kopi (25)
# correction(kpo) => kp (5); expected kopi (25)
# correction(matari) => materi (12); expected matahari (33)
# correction(bhsa) => bisa (182); expected bahasa (203)
# correction(jamu) => jamu (2); expected jam (51)
# correction(mja) => ma (10); expected meja (8)
# correction(meji) => mei (72); expected meja (8)
# correction(pushtaha) => pustaka (2); expected pustaha (0)
# correction(pusthaha) => pustaka (2); expected pustaha (0)
# correction(pustaja) => pustaka (2); expected pustaha (0)
# correction(dwitungal) => dwitungal (0); expected dwitunggal (0)
# correction(dwitunggall) => dwitunggall (0); expected dwitunggal (0)
# correction(dwitunggol) => dwitunggol (0); expected dwitunggal (0)
# correction(transenden) => transgender (5); expected transenden (0)
# correction(transendenn) => transendenn (0); expected transenden (0)
# correction(transindan) => transindan (0); expected transenden (0)
# correction(syapat) => syarat (8); expected syafaat (0)
# correction(syafaatt) => syafaatt (0); expected syafaat (0)
# correction(syafat) => syarat (8); expected syafaat (0)
# correction(desentralisass) => desentralisass (0); expected desentralisasi (0)
# correction(desentralysasi) => desentralysasi (0); expected desentralisasi (0)
# correction(abduleh) => abdullah (11); expected abdulah (0)
# correction(abdulahh) => abdullah (11); expected abdulah (0)
# correction(abdullah) => abdullah (11); expected abdulah (0)
# correction(ksenufobi) => ksenufobi (0); expected xenofobi (0)
# correction(ksenufobii) => ksenufobii (0); expected xenofobi (0)
# correction(ksenufoby) => ksenufoby (0); expected xenofobi (0)
# correction(kataliss) => katniss (4); expected katalis (0)
# correction(kataliis) => natalis (4); expected katalis (0)
# correction(katalys) => katanya (7); expected katalis (0)
# correction(astronommy) => astronomis (1); expected astronomi (1)
# correction(perspeksi) => perspektif (2); expected persepsi (1)
# correction(monnott) => monnott (0); expected monoton (1)
# correction(anologii) => antologi (3); expected analogi (2)
# correction(analogey) => analog (2); expected analogi (2)
# correction(sttrategis) => strategis (6); expected stategis (0)
# correction(stategiss) => strategis (6); expected stategis (0)
# correction(stategi) => strategi (6); expected stategis (0)
# correction(olligarki) => olligarki (0); expected oligarki (0)
# correction(oligarqi) => oligarqi (0); expected oligarki (0)
# correction(oligarky) => oligarky (0); expected oligarki (0)
# correction(obstruksii) => obstruksii (0); expected obstruksi (0)
# correction(obstroksi) => obstroksi (0); expected obstruksi (0)
# correction(obsturksi) => obsturksi (0); expected obstruksi (0)
# correction(paraddox) => paraddox (0); expected paradoks (1)
# correction(peripper) => peripper (0); expected perifer (0)
# correction(perifer) => primer (6); expected perifer (0)
# correction(periferr) => porifera (1); expected perifer (0)
# correction(olligopoli) => olligopoli (0); expected oligopoli (0)
# correction(oligopoly) => oligopoly (0); expected oligopoli (0)
# correction(oligopolly) => oligopolly (0); expected oligopoli (0)
# correction(detoksiifikasi) => detoksiifikasi (0); expected detoksifikasi (0)
# correction(detokssifikasi) => detokssifikasi (0); expected detoksifikasi (0)
# correction(detokifykasi) => detokifykasi (0); expected detoksifikasi (0)
# correction(mikroorgannisme) => mikroorgannisme (0); expected mikroorganisme (0)
# correction(mikroorganiisme) => mikroorganiisme (0); expected mikroorganisme (0)
# correction(mikroorganysme) => mikroorganysme (0); expected mikroorganisme (0)
# correction(elektrophoresis) => elektrophoresis (0); expected elektroforesis (0)
# correction(elektroforresis) => elektroforresis (0); expected elektroforesis (0)
# correction(elektrforesis) => elektrforesis (0); expected elektroforesis (0)
# correction(patologi) => mitologi (4); expected patologi (0)
# correction(patologii) => patologii (0); expected patologi (0)
# correction(patologgy) => patologgy (0); expected patologi (0)
# correction(hommogenitas) => hommogenitas (0); expected homogenitas (0)
# correction(homogenytas) => homogenytas (0); expected homogenitas (0)
# correction(homogenyty) => homogenyty (0); expected homogenitas (0)
# correction(meteorologi) => metodologi (2); expected meteorologi (0)
# correction(meteorologii) => meteorologii (0); expected meteorologi (0)
# correction(meteorrologi) => meteorrologi (0); expected meteorologi (0)
# correction(enigmathik) => enigmathik (0); expected enigmatik (0)
# correction(enigmatikk) => enigmatikk (0); expected enigmatik (0)
# correction(enigmetik) => enigmetik (0); expected enigmatik (0)
# correction(simbolyc) => simbol (20); expected simbolik (2)
# correction(sinchronis) => sinchronis (0); expected singkronis (0)
# correction(singchroniss) => singchroniss (0); expected singkronis (0)
# correction(sinkronis) => sinkronis (0); expected singkronis (0)
# correction(monnopolly) => monnopolly (0); expected monopoli (5)
# correction(kriitis) => kritis (5); expected kritikus (12)
# correction(enttropi) => enttropi (0); expected entropi (0)
# correction(entropii) => entropii (0); expected entropi (0)
# correction(entroppy) => entroppy (0); expected entropi (0)
# correction(dogmatic) => dogmatic (0); expected dogmatis (0)
# correction(dogmatiss) => dogmatiss (0); expected dogmatis (0)
# correction(dogmattis) => dogmattis (0); expected dogmatis (0)
# correction(silhuet) => silhuet (0); expected siluet (0)
# correction(sileut) => silat (3); expected siluet (0)
# correction(silyuet) => silyuet (0); expected siluet (0)
# correction(skepsisisme) => skepsisisme (0); expected skeptisisme (0)
# correction(skeptisissme) => skeptisissme (0); expected skeptisisme (0)
# correction(skecptisisme) => skecptisisme (0); expected skeptisisme (0)
# correction(hegemoneye) => hegemoneye (0); expected hegemoni (1)
# correction(dystopia) => distopian (1); expected distopia (0)
# correction(disttopia) => distopian (1); expected distopia (0)
# correction(distopya) => distopian (1); expected distopia (0)
# correction(ultraviolett) => ultraviolett (0); expected ultraviolet (0)
# correction(ultraviiolet) => ultraviiolet (0); expected ultraviolet (0)
# correction(ultravyolet) => ultravyolet (0); expected ultraviolet (0)
# correction(provokattif) => provokattif (0); expected provokatif (0)
# correction(provockatif) => provockatif (0); expected provokatif (0)
# correction(provokattiff) => provokattiff (0); expected provokatif (0)
# correction(abstaksi) => abstaksi (0); expected abstraksi (0)
# correction(abstakssi) => abstakssi (0); expected abstraksi (0)
# correction(abstraksi) => atraksi (3); expected abstraksi (0)
# correction(indiigo) => indiigo (0); expected indigo (0)
# correction(indygo) => indo (5); expected indigo (0)
# correction(indiggo) => indiggo (0); expected indigo (0)
# correction(othentik) => othentik (0); expected otentik (0)
# correction(oentik) => bentuk (100); expected otentik (0)
# correction(otenthik) => otenthik (0); expected otentik (0)
# correction(didaktiik) => didaktiik (0); expected didaktik (0)
# correction(didaktyk) => didaktyk (0); expected didaktik (0)
# correction(didaktic) => didaki (1); expected didaktik (0)
# correction(kollaboratif) => kollaboratif (0); expected kolaboratif (0)
# correction(kolaborattif) => kolaborattif (0); expected kolaboratif (0)
# correction(kolabooratif) => kolabooratif (0); expected kolaboratif (0)
# correction(eksploration) => exploration (1); expected eksplorasi (1)
# correction(affinitas) => affinitas (0); expected afinitas (0)
# correction(afinitass) => afinitass (0); expected afinitas (0)
# correction(affiinity) => affiinity (0); expected afinitas (0)
# correction(kontradikssi) => kontradikssi (0); expected kontradiksi (0)
# correction(kontraddiksi) => kontraddiksi (0); expected kontradiksi (0)
# correction(kontraddiksy) => kontraddiksy (0); expected kontradiksi (0)
# correction(symmetrii) => symmetrii (0); expected simetri (2)
# correction(symmetry) => symmetry (0); expected simetri (2)
# correction(permutasii) => permutasii (0); expected permutasi (0)
# correction(permuutasi) => permuutasi (0); expected permutasi (0)
# correction(permuutassy) => permuutassy (0); expected permutasi (0)
# correction(ekssekussy) => ekssekussy (0); expected eksekusi (2)
# correction(eksucution) => eksucution (0); expected eksekusi (2)
# correction(atmospherr) => atmospherr (0); expected atmosfer (8)
# correction(termynologi) => termynologi (0); expected terminologi (0)
# correction(terminollogy) => terminollogy (0); expected terminologi (0)
# correction(terminologii) => terminologii (0); expected terminologi (0)
# correction(komplexiti) => komplexiti (0); expected kompleksitas (1)
# correction(astromoniis) => astromoniis (0); expected astronomis (1)
# correction(diskurssus) => diskurssus (0); expected diskursus (0)
# correction(diskursuss) => diskursuss (0); expected diskursus (0)
# correction(diskus) => diskusi (5); expected diskursus (0)
# correction(enttropii) => enttropii (0); expected entropi (0)
# correction(entropy) => entropy (0); expected entropi (0)
# correction(entrophy) => entrophy (0); expected entropi (0)
# correction(agnostikk) => agnostikk (0); expected agnostik (0)
# correction(agnossstik) => agnossstik (0); expected agnostik (0)
# correction(agnostic) => agnostic (0); expected agnostik (0)
# correction(konnsolidasi) => konnsolidasi (0); expected konsolidasi (0)
# correction(konsoliddasi) => konsoliddasi (0); expected konsolidasi (0)
# correction(konsolidaasi) => konsolidaasi (0); expected konsolidasi (0)
# correction(rellative) => rellative (0); expected relatif (16)
# correction(relattive) => relattive (0); expected relatif (16)
# correction(asymetrii) => asimetris (1); expected asimetri (0)
# correction(asymettri) => asymettri (0); expected asimetri (0)
# correction(asimettry) => asimettry (0); expected asimetri (0)
# correction(proactif) => proactif (0); expected proaktif (0)
# correction(proaktiff) => proaktiff (0); expected proaktif (0)
# correction(proaktiif) => proaktiif (0); expected proaktif (0)
# correction(individuallis) => individuallis (0); expected individualis (0)
# correction(individualiis) => individualiis (0); expected individualis (0)
# correction(individualliss) => individualliss (0); expected individualis (0)
# correction(symmetrii) => symmetrii (0); expected simetri (2)
# correction(symmerty) => symmerty (0); expected simetri (2)
# correction(philanthropi) => philanthropi (0); expected filantropi (1)
# correction(ethis) => etnis (11); expected etis (2)
# correction(etiis) => etnis (11); expected etis (2)
# correction(etyis) => etnis (11); expected etis (2)
# correction(kurattif) => kurattif (0); expected kuratif (0)
# correction(kuratiff) => kuratiff (0); expected kuratif (0)
# correction(kurattiif) => kurattiif (0); expected kuratif (0)
# correction(optimiis) => optimus (2); expected optimis (0)
# correction(optiimis) => optimus (2); expected optimis (0)
# correction(optimiss) => optimus (2); expected optimis (0)
# correction(kontraddiksi) => kontraddiksi (0); expected kontradiksi (0)
# correction(kontraddikss) => kontraddikss (0); expected kontradiksi (0)
# correction(kontradiksy) => kontradiksy (0); expected kontradiksi (0)
# correction(konntroverssy) => konntroverssy (0); expected kontroversi (12)
# correction(inckonsistensi) => inckonsistensi (0); expected inkonsistensi (0)
# correction(inkonsistensy) => inkonsistensy (0); expected inkonsistensi (0)
# correction(inkonsistiensi) => inkonsistiensi (0); expected inkonsistensi (0)
# correction(diiksii) => diikuti (16); expected diksi (2)
# correction(konnspirasi) => konnspirasi (0); expected konspirasi (0)
# correction(konspirassy) => konspirassy (0); expected konspirasi (0)
# correction(konnspiry) => konnspiry (0); expected konspirasi (0)
# correction(kritissi) => kritis (5); expected kritisi (0)
# correction(kriitisy) => kritis (5); expected kritisi (0)
# correction(krittisi) => kritis (5); expected kritisi (0)
# correction(termynologi) => termynologi (0); expected terminologi (0)
# correction(terminollogy) => terminollogy (0); expected terminologi (0)
# correction(terminologii) => terminologii (0); expected terminologi (0)
# correction(aksyoma) => aksyoma (0); expected aksioma (0)
# correction(aksiomma) => aksiomma (0); expected aksioma (0)
# correction(aksiomaa) => aksiomaa (0); expected aksioma (0)
# correction(diffusi) => diskusi (5); expected difusi (0)
# correction(diffussi) => diffussi (0); expected difusi (0)
# correction(dyfusi) => fusi (3); expected difusi (0)
# correction(insentiff) => insentiff (0); expected insentif (0)
# correction(insentyf) => insentyf (0); expected insentif (0)
# correction(insentiv) => insentiv (0); expected insentif (0)
# correction(konnesi) => kondisi (39); expected konsesi (0)
# correction(konnnesi) => konvensi (6); expected konsesi (0)
# correction(konnesy) => kontes (8); expected konsesi (0)
# correction(anologii) => antologi (3); expected analogi (2)
# correction(anallloogi) => anallloogi (0); expected analogi (2)
# correction(mikrooskopis) => mikroskopik (1); expected mikroskopis (0)
# correction(mikrooskoppis) => mikrooskoppis (0); expected mikroskopis (0)
# correction(mikroscopy) => mikroskop (2); expected mikroskopis (0)
# correction(solliter) => collier (1); expected soliter (0)
# correction(soliterr) => soliterr (0); expected soliter (0)
# correction(solitir) => politik (58); expected soliter (0)
# correction(paralllel) => parallel (1); expected paralel (3)
# correction(paralleel) => parallel (1); expected paralel (3)
# correction(diskontinyuitas) => diskontinyuitas (0); expected diskontinuitas (0)
# correction(diskontinuity) => diskontinuity (0); expected diskontinuitas (0)
# correction(diskontinuittas) => diskontinuittas (0); expected diskontinuitas (0)
# correction(regenerrassii) => regenerrassii (0); expected regenerasi (2)
# correction(hibridaa) => hibridaa (0); expected hibrida (0)
# correction(hibridda) => hibridda (0); expected hibrida (0)
# correction(hibridda) => hibridda (0); expected hibrida (0)
# correction(konnformitas) => konnformitas (0); expected konformitas (0)
# correction(konformittas) => konformittas (0); expected konformitas (0)
# correction(konnformity) => konnformity (0); expected konformitas (0)
# correction(anarchy) => anarchy (0); expected anarki (1)
# correction(perturbassy) => perturbassy (0); expected perturbasi (0)
# correction(perturbbasi) => perturbbasi (0); expected perturbasi (0)
# correction(perturbasii) => perturbasii (0); expected perturbasi (0)
# correction(distorrsi) => distorrsi (0); expected distorsi (0)
# correction(distorti) => distorti (0); expected distorsi (0)
# correction(distoorsy) => distoorsy (0); expected distorsi (0)
# correction(inkarnation) => inkarnation (0); expected inkarnasi (2)
# correction(konnfrontasi) => konnfrontasi (0); expected konfrontasi (0)
# correction(konfrontassy) => konfrontassy (0); expected konfrontasi (0)
# correction(konfronthasi) => konfronthasi (0); expected konfrontasi (0)
# correction(dynnasty) => dynasty (1); expected dinasti (27)
# correction(divvergen) => divergent (1); expected divergen (0)
# correction(diverggenn) => divergent (1); expected divergen (0)
# correction(divurgen) => divergent (1); expected divergen (0)
# correction(kontraddiksi) => kontraddiksi (0); expected kontradiksi (0)
# correction(kontradikssi) => kontradikssi (0); expected kontradiksi (0)
# correction(kontradiksy) => kontradiksy (0); expected kontradiksi (0)
# correction(inklussif) => inklusi (1); expected inklusif (0)
# correction(inkluusiif) => inkluusiif (0); expected inklusif (0)
# correction(inklussiv) => inklusi (1); expected inklusif (0)
# correction(monnotoni) => monoton (1); expected monotoni (0)
# correction(monotttoni) => monotttoni (0); expected monotoni (0)
# correction(monotonni) => monoton (1); expected monotoni (0)
# correction(diammetral) => diammetral (0); expected diametral (0)
# correction(diammeteral) => diammeteral (0); expected diametral (0)
# correction(diammetrall) => diammetrall (0); expected diametral (0)
# correction(sterilissasi) => sterilissasi (0); expected sterilisasi (0)
# correction(sterillisasi) => serialisasi (1); expected sterilisasi (0)
# correction(sterilysasi) => sterilysasi (0); expected sterilisasi (0)
# correction(assimilassi) => assimilassi (0); expected asimilasi (0)
# correction(assimilasy) => assimilasy (0); expected asimilasi (0)
# correction(assimilasy) => assimilasy (0); expected asimilasi (0)
# correction(klandesstinn) => klandesstinn (0); expected klandestin (0)
# correction(klandestinn) => klandestinn (0); expected klandestin (0)
# correction(clandestin) => clandestin (0); expected klandestin (0)
# correction(perihellion) => perihellion (0); expected perihelion (0)
# correction(periheliion) => periheliion (0); expected perihelion (0)
# correction(periheleon) => periheleon (0); expected perihelion (0)
# 54% of 600 correct (36% unknown) at 14 words per second
